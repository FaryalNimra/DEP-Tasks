# %% [markdown]
# **Step 1: Load Your Data from Your Drive Using Upload Button**

# %% [markdown]
# **Step 2: Data Cleaning and Preprocessing**

# %%
import pandas as pd #Python Libraray
my_data = '/content/Online Shopping Store Transaction Data.csv'
df = pd.read_csv(my_data) # csv is a function used for comma separated files

# %%
print(df.head(3)) # for displaying 3 rows of my data
# Out:
#    Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0           0     17850.0      M  Chicago           12.0         16679.0
# 1           1     17850.0      M  Chicago           12.0         16680.0
# 2           2     17850.0      M  Chicago           12.0         16696.0
#
#   Transaction_Date     Product_SKU  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
#
#                                  Product_Description Product_Category  ...  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA  ...
#
#    Avg_Price  Delivery_Charges  Coupon_Status  GST      Date Offline_Spend  \
# 0     153.71               6.5           Used  0.1  1/1/2019        4500.0
# ...

# %%
df.isnull()#for checking null values in dataset it gives you result in form of true and false
# Out:
#        Unnamed: 0  CustomerID  Gender  Location  Tenure_Months  \
# 0           False       False   False     False          False
# 1           False       False   False     False          False
# 2           False       False   False     False          False
# 3           False       False   False     False          False
# 4           False       False   False     False          False
# ...           ...         ...     ...       ...            ...
# 52950       False        True    True      True           True
# 52951       False        True    True      True           True
# 52952       False        True    True      True           True
# 52953       False        True    True      True           True
# 52954       False        True    True      True           True
#
#        Transaction_ID  Transaction_Date  Product_SKU  Product_Description  \
# 0               False             False        False                False
# ...

# %%
print(df.isnull().sum()) # This function will give you the sum it is more appropriate
# Out:
# Unnamed: 0               0
# CustomerID              31
# Gender                  31
# Location                31
# Tenure_Months           31
# Transaction_ID          31
# Transaction_Date        31
# Product_SKU             31
# Product_Description     31
# Product_Category         0
# Quantity                31
# Avg_Price               31
# Delivery_Charges        31
# Coupon_Status           31
# GST                     31
# Date                    31
# Offline_Spend           31
# Online_Spend            31
# Month                    0
# Coupon_Code            400
# Discount_pct           400
# dtype: int64

# %% [markdown]
# **The above data is giving me the count of Null values in my dataset so Now Drop the null values using dropna() Function**

# %%
df = df.dropna()
df.head(3)
# Out:
#    Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0           0     17850.0      M  Chicago           12.0         16679.0
# 1           1     17850.0      M  Chicago           12.0         16680.0
# 2           2     17850.0      M  Chicago           12.0         16696.0
#
#   Transaction_Date     Product_SKU  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
#
#                                  Product_Description Product_Category  ...  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA  ...
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA  ...
#
#    Avg_Price  Delivery_Charges  Coupon_Status  GST      Date Offline_Spend  \
# 0     153.71               6.5           Used  0.1  1/1/2019        4500.0
# ...

# %%
print(df.isnull().sum()) # This function will give you the sum it is more appropriate
# Out:
# Unnamed: 0             0
# CustomerID             0
# Gender                 0
# Location               0
# Tenure_Months          0
# Transaction_ID         0
# Transaction_Date       0
# Product_SKU            0
# Product_Description    0
# Product_Category       0
# Quantity               0
# Avg_Price              0
# Delivery_Charges       0
# Coupon_Status          0
# GST                    0
# Date                   0
# Offline_Spend          0
# Online_Spend           0
# Month                  0
# Coupon_Code            0
# Discount_pct           0
# dtype: int64

# %% [markdown]
# **Our Data Cleaning set has been done here**

# %% [markdown]
# **Step 3: Data Analysis**

# %%
import matplotlib.pyplot as plt
import seaborn as sns #importing libraries

# %%
df.describe() # Give you the summary of your Clean Data
# Out:
#          Unnamed: 0    CustomerID  Tenure_Months  Transaction_ID  \
# count  52524.000000  52524.000000   52524.000000    52524.000000
# mean   26372.364176  15345.347213      26.140393    32445.093367
# std    15232.596810   1766.862675      13.473500     8654.724704
# min        0.000000  12346.000000       2.000000    16679.000000
# 25%    13170.750000  13869.000000      15.000000    25404.000000
# 50%    26361.500000  15311.000000      27.000000    32678.000000
# 75%    39557.250000  16996.000000      37.000000    39174.250000
# max    52923.000000  18283.000000      50.000000    48497.000000
#
#            Quantity     Avg_Price  Delivery_Charges           GST  \
# count  52524.000000  52524.000000      52524.000000  52524.000000
# mean       4.500171     52.429089         10.476922      0.137433
# std       20.159985     64.156649         19.343153      0.045865
# min        1.000000      0.390000          0.000000      0.050000
# ...

# %% [markdown]
# ScatterPlot is To visualize the relationship between two numerical variables
#
# Online_Spend which is the Amount of money spent online.
# Offline_Spend which is the Amount of money spent offline.
# Gender is a Categorical variable used for coloring the points in the scatter plot.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Online_Spend', y='Offline_Spend', hue='Gender', data=df)
plt.title('Scatter plot of Online Spend vs Offline Spend by Gender')
plt.show()

# %% [markdown]
# Histogram Shows the distribution of average product prices. It will Help us to understand pricing patterns and identify any skewness or outliers.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Avg_Price'], kde=True)
plt.title('Distribution of Average Price')
plt.xlabel('Average Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Bar Plot:Shows the average amount spent online by each gender.It Helps to identify if there is a significant difference in online spending between genders.

# %%
import numpy as np
plt.figure(figsize=(10, 6))
sns.barplot(x='Gender', y='Online_Spend', data=df, estimator=np.mean)
plt.title('Average Online Spend by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Online Spend')
plt.show()

# %% [markdown]
# Box Plot visualizes the spread and outliers in offline spending for each gender.It
# Helps to understand spending behavior and identify any significant differences.
# ---

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Gender', y='Offline_Spend', data=df)
plt.title('Distribution of Offline Spend by Gender')
plt.xlabel('Gender')
plt.ylabel('Offline Spend')
plt.show()

# %% [markdown]
#  Heatmap shows correlations between numerical features,helps to identify which features are strongly related to each other.

# %%
numerical_df = df.select_dtypes(include=[float, int])


correlation_matrix = numerical_df.corr() # function

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Pair Plot help to
# Visualizes pairwise relationships and distributions of numerical features and
# to see overall patterns and potential correlations.

# %%
subset = df[['Tenure_Months', 'Quantity', 'Avg_Price', 'Offline_Spend', 'Online_Spend']]
sns.pairplot(subset)
plt.show()

# %% [markdown]
# Step 4: K-means clustering algorithm to segment the customers based on their purchasing behavior.

# %% [markdown]
# Firstly use Elbow method to find no of clusters

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Select relevant features for clustering
features = ['Tenure_Months', 'Quantity', 'Avg_Price', 'Offline_Spend', 'Online_Spend']

# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df[features])

# Calculate WCSS for different number of clusters
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(scaled_features)
    wcss.append(kmeans.inertia_)

# Plot the elbow curve
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.title('Elbow Method For Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# So my Elbow is something 5 i would use 5 I can also choose 4 and 6

# %%
# Applying K-means clustering with the optimal number of clusters
optimal_clusters = 5
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
df['Cluster'] = kmeans.fit_predict(scaled_features)

# Adding cluster labels to the original dataframe
print("\nDataset with cluster labels:")
print(df.head())
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Dataset with cluster labels:
#    Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0           0     17850.0      M  Chicago           12.0         16679.0
# 1           1     17850.0      M  Chicago           12.0         16680.0
# 2           2     17850.0      M  Chicago           12.0         16696.0
# 3           3     17850.0      M  Chicago           12.0         16699.0
# 4           4     17850.0      M  Chicago           12.0         16700.0
#
#   Transaction_Date     Product_SKU  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
# 3       2019-01-01  GGOENEBQ079099
# 4       2019-01-01  GGOENEBJ079499
#
# ...

# %% [markdown]
# **Last Step: Visualization of Customer Segments**

# %%
# Visualizing the clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Online_Spend', y='Offline_Spend', hue='Cluster', data=df, palette='viridis', alpha=0.7)
plt.title('Clusters of Customers Based on Online and Offline Spend')
plt.xlabel('Online Spend')
plt.ylabel('Offline Spend')
plt.show()

# %%
# Scatter plot to visualize clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Online_Spend', y='Offline_Spend', hue='Cluster', data=df, palette='Set1')
plt.title('Customer Segments based on Online and Offline Spend')
plt.show()

# %%
# Scatter plot for different features
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Quantity', y='Avg_Price', hue='Cluster', data=df, palette='Set2')
plt.title('Customer Segments based on Quantity and Average Price')
plt.show()
